# %%
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import math
from datetime import datetime
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
mmt = pd.read_csv('data/mmt_parsed.csv')

# %%
mmt.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                  0  65000000
# 2                                                  0  16000000
# 3                                                  0  60000000
# 4                                                  0  35000000
#
#                                               genres    imdb_id  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  tt0114709
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  tt0113497
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0114885
# 3  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...  tt0113277
# 4  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  tt0114576
#
#   original_language  popularity release_date    revenue  runtime  \
# 0                en   21.946943   1995-10-30  373554033     81.0
# 1                en   17.015539   1995-12-15  262797249    104.0
# ...

# %%
mmt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5154 entries, 0 to 5153
# Data columns (total 38 columns):
# belongs_to_collection             5154 non-null object
# budget                            5154 non-null int64
# genres                            5154 non-null object
# imdb_id                           5154 non-null object
# original_language                 5154 non-null object
# popularity                        5154 non-null float64
# release_date                      5154 non-null object
# revenue                           5154 non-null int64
# runtime                           5154 non-null float64
# words_in_title                    5154 non-null int64
# words_in_original_title           5154 non-null int64
# numVotes                          5154 non-null int64
# averageRating                     5154 non-null float64
# Crime                             5154 non-null int64
# Action                            5154 non-null int64
# ...

# %%
len(mmt[mmt['numVotes'] < 1000])
# Out:
# 0

# %%
mmt[mmt['averageRating'] < 2]
# Out:
#      belongs_to_collection    budget  \
# 3111                     0  25000000
# 4471                     0  65000000
# 4480                     0  13000000
#
#                                                  genres    imdb_id  \
# 3111  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...  tt1213644
# 4471  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...  tt0249516
# 4480  [{'id': 99, 'name': 'Documentary'}, {'id': 104...  tt1702443
#
#      original_language  popularity release_date   revenue  runtime  \
# 3111                en   11.634132   2008-08-29  14109284     87.0
# 4471                en    6.693589   2012-06-15     73706     87.0
# 4480                en    5.892524   2011-02-11  98441954    105.0
#
#       words_in_title        ...          Music  Fantasy  Romance  History  \
# 3111               2        ...              0        0        0        0
# 4471               1        ...              0        0        0        0
# ...

# %%
mmt['original_language'].value_counts()
# Out:
# en    4621
# hi      98
# fr      88
# ru      42
# ja      41
# es      37
# zh      29
# it      26
# ta      25
# ko      23
# de      21
# cn      15
# da      11
# ml      10
# te       8
# sv       6
# pt       6
# nl       5
# no       4
# tr       4
# ro       4
# pl       4
# id       3
# sr       3
# xx       2
# he       2
# th       2
# hu       2
# fi       2
# af       1
# el       1
# mr       1
# fa       1
# ur       1
# nb       1
# ca       1
# bm       1
# is       1
# kn       1
# Name: original_language, dtype: int64

# %%
mmt['belongs_to_collection']  = mmt['belongs_to_collection'].apply(lambda x: 1 if x != '0' else 0)

# %%
mmt['date'] = pd.to_datetime(mmt['release_date'], format='%Y-%m-%d')
mmt['release_date'] = mmt['date'].values.astype(np.int64) // 10 ** 9

# %%
mmt.drop([ 'date', 'imdb_id', 'genres' ], axis=1, inplace=True)

# %% [markdown]
# One hot encoding original_language

# %%
mmt.drop(['original_language'], axis=1, inplace=True)

# %%
mmt.head()
# Out:
#    belongs_to_collection    budget  popularity  release_date    revenue  \
# 0                      1  30000000   21.946943     815011200  373554033
# 1                      0  65000000   17.015539     818985600  262797249
# 2                      0  16000000    3.859495     819590400   81452156
# 3                      0  60000000   17.924927     818985600  187436818
# 4                      0  35000000    5.231580     819590400   64350171
#
#    runtime  words_in_title  words_in_original_title  numVotes  averageRating  \
# 0     81.0               2                        2    761501            8.3
# 1    104.0               1                        1    260244            6.9
# 2    127.0               3                        3      8483            5.8
# 3    170.0               1                        1    508869            8.2
# 4    106.0               2                        2     29156            5.7
#
#          ...          Music  Fantasy  Romance  History  Animation  \
# ...

# %%
mmt.to_csv("data/mmt_prepared.csv", index=False)
